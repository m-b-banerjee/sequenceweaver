# %% [markdown]
# <a href="https://colab.research.google.com/github/m-b-banerjee/sequenceweaver/blob/main/VisualStory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 5
num2 = 10
sum_of_numbers = num1 + num2
print(f"The sum of {num1} and {num2} is: {sum_of_numbers}")
# Out:
# The sum of 5 and 10 is: 15

# %%
num3 = num2-num1
print(num3)
# Out:
# 5

# %%
num4 = num1-num3
print(num4)
# Out:
# 0

# %%
print('The sum of 5 and 10 is: 15')
# Out:
# The sum of 5 and 10 is: 15
